# %%
import soccerdata as sd

import json
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mplsoccer import Pitch
pd.set_option('display.max_columns', 38)
# Out:
# [05/11/24 09:33:15] INFO     No custom team name replacements found. You can configure these in       ]8;id=156951;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=716359;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/soccerdata/_config.py#87\87]8;;\
#                              /Users/rustya/soccerdata/config/teamname_replacements.json.
#                     INFO     No custom league dict found. You can configure additional leagues in    ]8;id=637090;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/soccerdata/_config.py\_config.py]8;;\:]8;id=666976;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/soccerdata/_config.py#177\177]8;;\
#                              /Users/rustya/soccerdata/config/league_dict.json.

# %% [markdown]
# # Parse data

# %%
who = sd.WhoScored(leagues='ENG-Premier League', seasons=[23,22,21], headless=False)
who.read_events()
# Out:
# [04/11/24 01:18:39] INFO     Saving cached data to /Users/rustya/soccerdata/data/WhoScored            ]8;id=797618;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/soccerdata/_common.py\_common.py]8;;\:]8;id=822756;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/soccerdata/_common.py#92\92]8;;\
# [04/11/24 01:18:40] INFO     patching driver executable /Users/rustya/Library/Application            ]8;id=263887;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/undetected_chromedriver/patcher.py\patcher.py]8;;\:]8;id=254012;file:///Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/undetected_chromedriver/patcher.py#346\346]8;;\
#                              Support/undetected_chromedriver/undetected_chromedriver
# ...
